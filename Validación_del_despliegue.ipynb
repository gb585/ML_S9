# %% [markdown]
# # Tabla de resultados para jugar con la aplicación Streamlit

# %% [markdown]
# El modelo desplegado en Streamlit se halla en: https://rt57xrrn66udzjrf8stvfj.streamlit.app/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Estos son los resultados del modelo de regresión logística con todo el dataset original winsorizado para clasificar si un cliente contratará o no un depósito, con las características, **housing, balance y cat_poutcome_success**.
#
# El objetivo, de este ipynb, es  dar del dataset original df_bank_marketing y con la Winsorización aplicada, diferentes cálculos de la variable predictora y (depósito) con el módelo.
# De esta manera, podremos probar en Streamlit si los cálculos coinciden probando con distintos valores de características. Las simulaciones estan al final del documento.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Simulaciones

# %% [markdown]
# **Simulación 1**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Verfificado que el despligue funciona correctamente para esta simulación

# %% [markdown]
# **Simulación 2**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Simulación correcta
